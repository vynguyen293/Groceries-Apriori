# %% [markdown]
# ***Nguyen Thi Tuong Vy***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
data = pd.read_excel('ItemList.xlsx', header=None, engine='openpyxl')

# %%
data.shape
# Out:
# (14963, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14963 entries, 0 to 14962
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       14963 non-null  object
#  1   1       14963 non-null  object
#  2   2       4883 non-null   object
#  3   3       2185 non-null   object
#  4   4       795 non-null    object
#  5   5       451 non-null    object
#  6   6       276 non-null    object
#  7   7       196 non-null    object
#  8   8       51 non-null     object
#  9   9       1 non-null      object
#  10  10      1 non-null      object
# dtypes: object(11)
# memory usage: 1.3+ MB

# %%
data
# Out:
#                           0                   1                    2       3   \
# 0                    sausage          whole milk  semi-finished bread  yogurt
# 1                 whole milk              pastry          salty snack     NaN
# 2                canned beer     misc. beverages                  NaN     NaN
# 3                    sausage    hygiene articles                  NaN     NaN
# 4                       soda  pickled vegetables                  NaN     NaN
# ...                      ...                 ...                  ...     ...
# 14958         tropical fruit             berries     other vegetables  yogurt
# 14959          bottled water               herbs                  NaN     NaN
# 14960  fruit/vegetable juice              onions                  NaN     NaN
# 14961                   soda     root vegetables  semi-finished bread     NaN
# 14962           bottled beer    other vegetables                  NaN     NaN
#
# ...

# %% [markdown]
# # Data Pre-processing

# %%
dataset = []
for i in range(0, data.shape[0]):
    dataset.append([str(data.values[i,j]) for j in range(0, data.shape[1])])

# %%
dataset
# Out:
# [['sausage',
#   'whole milk',
#   'semi-finished bread',
#   'yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole milk',
#   'pastry',
#   'salty snack',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['canned beer',
#   'misc. beverages',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['sausage',
#   'hygiene articles',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soda',
#   'pickled vegetables',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frankfurter',
#   'curd',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['sausage',
#   'whole milk',
#   'rolls/buns',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole milk',
# ...

# %%
te = TransactionEncoder()
te.fit(dataset)
te_ary = te.transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 14958                  False     False             False             False
# 14959                  False     False             False             False
# 14960                  False     False             False             False
# 14961                  False     False             False             False
# 14962                  False     False             False             False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14963 entries, 0 to 14962
# Columns: 168 entries, Instant food products to zwieback
# dtypes: bool(168)
# memory usage: 2.4 MB

# %%
df = df.drop(['nan'], axis=1)

# %%
df.shape
# Out:
# (14963, 167)

# %% [markdown]
# # Use APRIORI

# %% [markdown]
# **Choose support = 0.001**

# %%
frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True)
frequent_itemsets
# Out:
#       support                           itemsets
# 0    0.004010            (Instant food products)
# 1    0.021386                         (UHT-milk)
# 2    0.001470                 (abrasive cleaner)
# 3    0.001938                 (artif. sweetener)
# 4    0.008087                    (baking powder)
# ..        ...                                ...
# 745  0.001136  (whole milk, sausage, rolls/buns)
# 746  0.001002     (soda, whole milk, rolls/buns)
# 747  0.001337   (yogurt, whole milk, rolls/buns)
# 748  0.001069        (soda, sausage, whole milk)
# 749  0.001470      (yogurt, sausage, whole milk)
#
# [750 rows x 2 columns]

# %% [markdown]
# **Choose confidence = 0.005**

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric='confidence', min_threshold=0.005)
# Out:
#                 antecedents            consequents  antecedent support  \
# 0                (UHT-milk)        (bottled water)            0.021386
# 1           (bottled water)             (UHT-milk)            0.060683
# 2        (other vegetables)             (UHT-milk)            0.122101
# 3                (UHT-milk)     (other vegetables)            0.021386
# 4                (UHT-milk)           (rolls/buns)            0.021386
# ...                     ...                    ...                 ...
# 1233   (yogurt, whole milk)              (sausage)            0.011161
# 1234  (sausage, whole milk)               (yogurt)            0.008955
# 1235               (yogurt)  (sausage, whole milk)            0.085879
# 1236              (sausage)   (yogurt, whole milk)            0.060349
# 1237           (whole milk)      (yogurt, sausage)            0.157923
#
#       consequent support   support  confidence      lift  leverage  conviction
# ...

# %% [markdown]
# **Choose lift = 1.4**

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1.4)
rules
# Out:
#               antecedents            consequents  antecedent support  \
# 0             (beverages)              (sausage)            0.016574
# 1               (sausage)            (beverages)            0.060349
# 2   (specialty chocolate)         (citrus fruit)            0.015973
# 3          (citrus fruit)  (specialty chocolate)            0.053131
# 4                  (curd)              (sausage)            0.033683
# 5               (sausage)                 (curd)            0.060349
# 6                (yogurt)            (detergent)            0.085879
# 7             (detergent)               (yogurt)            0.008621
# 8                 (flour)       (tropical fruit)            0.009757
# 9        (tropical fruit)                (flour)            0.067767
# 10            (pip fruit)          (hard cheese)            0.049054
# 11          (hard cheese)            (pip fruit)            0.014703
# 12              (napkins)               (pastry)            0.022121
# ...

# %%
rules.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         26 non-null     object
#  1   consequents         26 non-null     object
#  2   antecedent support  26 non-null     float64
#  3   consequent support  26 non-null     float64
#  4   support             26 non-null     float64
#  5   confidence          26 non-null     float64
#  6   lift                26 non-null     float64
#  7   leverage            26 non-null     float64
#  8   conviction          26 non-null     float64
# dtypes: float64(7), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# **Does the result have "sausage"?**

# %%
for row in rules.iterrows():
    if 'sausage' in row[1][0]:
        print(row)
# Out:
# (1, antecedents             (sausage)
# consequents           (beverages)
# antecedent support      0.0603489
# consequent support      0.0165742
# support                0.00153712
# confidence              0.0254707
# lift                      1.53676
# leverage               0.00053689
# conviction                1.00913
# Name: 1, dtype: object)
# (5, antecedents             (sausage)
# consequents                (curd)
# antecedent support      0.0603489
# consequent support      0.0336831
# support                0.00294059
# confidence              0.0487265
# lift                      1.44662
# leverage              0.000907851
# conviction                1.01581
# Name: 5, dtype: object)
# (19, antecedents                    (sausage)
# consequents           (whole milk, soda)
# antecedent support             0.0603489
# consequent support             0.0116287
# support                        0.0010693
# confidence                     0.0177187
# ...

# %% [markdown]
# ==> The result has "sausage". There are some items which are bought with "sausage" include:
# - beverages
# - curd
# - whole milk, soda
# - yogurt
# - whole milk
# - whole milk, yogurt

# %%
support = rules['support'].values
confidence = rules['confidence'].values
lift = rules['lift'].values

# %%
plt.figure(figsize=(8,5))
plt.scatter(support, confidence, s=lift*100, alpha=0.8, c=lift)
plt.xlabel('support')
plt.ylabel('confidence');

# %%
result = df.apply(pd.value_counts).fillna(0)
result
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# False                  14903     14643             14941             14934
# True                      60       320                22                29
#
#        baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# False           14960  14959          14842             14946  14455    14637
# True                3      4            121                17    508      326
#
#        ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# False  ...   14883    14912    14686               14309   14955        14604
# True   ...      80       51      277                 654       8          359
#
#        white wine  whole milk  yogurt  zwieback
# False       14788       12600   13678     14903
# True          175        2363    1285        60
#
# [2 rows x 167 columns]

# %%
df_true = result.iloc[1,:]
df_true
# Out:
# Instant food products      60
# UHT-milk                  320
# abrasive cleaner           22
# artif. sweetener           29
# baby cosmetics              3
#                          ...
# white bread               359
# white wine                175
# whole milk               2363
# yogurt                   1285
# zwieback                   60
# Name: True, Length: 167, dtype: int64

# %% [markdown]
# **Visualize 15 best selling products**

# %%
x = df_true.sort_values(ascending=False)
x
# Out:
# whole milk               2363
# other vegetables         1827
# rolls/buns               1646
# soda                     1453
# yogurt                   1285
#                          ...
# frozen chicken              5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: True, Length: 167, dtype: int64

# %%
most_products = x[:15]
most_products
# Out:
# whole milk          2363
# other vegetables    1827
# rolls/buns          1646
# soda                1453
# yogurt              1285
# root vegetables     1041
# tropical fruit      1014
# bottled water        908
# sausage              903
# citrus fruit         795
# pastry               774
# pip fruit            734
# shopping bags        712
# canned beer          702
# bottled beer         678
# Name: True, dtype: int64

# %%
pos = np.arange(len(most_products.values))
plt.figure(figsize=(10,6))
plt.bar(pos, most_products.values, align='center')
plt.xticks(pos, most_products.keys(), rotation='vertical')
plt.ylabel('Buying Times')
plt.xlabel('Names')
plt.title('15 best selling products');

# %% [markdown]
# 15 best selling products:
# **whole milk, other vegetables, rolls/buns, soda, yogurt, root vegetables, tropical fruit, bottled water, sausage, citrus fruit, pastry, pip fruit, shopping bags, canned beer, bottled beer**

# %% [markdown]
# **Visualize 15 worst selling products**

# %%
y = df_true.sort_values(ascending=True)
y
# Out:
# preservation products       1
# kitchen utensil             1
# baby cosmetics              3
# bags                        4
# frozen chicken              5
#                          ...
# yogurt                   1285
# soda                     1453
# rolls/buns               1646
# other vegetables         1827
# whole milk               2363
# Name: True, Length: 167, dtype: int64

# %%
least_products = y[:15]
least_products
# Out:
# preservation products     1
# kitchen utensil           1
# baby cosmetics            3
# bags                      4
# frozen chicken            5
# toilet cleaner            5
# rubbing alcohol           5
# make up remover           5
# salad dressing            6
# whisky                    8
# decalcifier               9
# hair spray                9
# liqueur                   9
# organic products         10
# specialty vegetables     11
# Name: True, dtype: int64

# %%
pos2 = np.arange(len(least_products.values))
plt.figure(figsize=(10,6))
plt.bar(pos2, least_products.values, align='center')
plt.xticks(pos2, least_products.keys(), rotation='vertical')
plt.ylabel('Buying Times')
plt.xlabel('Names')
plt.title('15 worst selling products');

# %% [markdown]
# 15 worst selling products:
# **preservation products, kitchen utensil, baby cosmetics, bags, frozen chicken, toilet cleaner, rubbing alcohol, make up remover, salad dressing, whisky, decalcifier, hair spray, liqueur, organic products, specialty vegetables**
